# %%
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('week4event.csv',header=None)
df
# Out:
#                0         1  2  3     4          5  6      7      8
# 0      3/18/2019   8:12:31  1  0    UP  Counter A  4  H2-L3  H2-L3
# 1      3/18/2019   8:31:31  1  0    UP  Counter A  4  H2-L3  H2-L3
# 2      3/18/2019   8:55:31  1  0    UP  Counter A  4  H2-L3  H2-L3
# 3      3/18/2019   8:56:31  2  0    UP  Counter A  4  H2-L3  H2-L3
# 4      3/18/2019   9:08:31  1  0    UP  Counter A  4  H2-L3  H2-L3
# ...          ...       ... .. ..   ...        ... ..    ...    ...
# 71735  6/21/2019  21:42:45  1  0  DOWN  Counter B  5  H1-L5  TOP5N
# 71736  6/21/2019  22:42:45  1  0  DOWN  Counter B  5  H1-L5  TOP5N
# 71737  6/22/2019  13:42:37  2  0  DOWN  Counter B  5  H1-L5  TOP5N
# 71738  6/22/2019  18:00:35  1  0  DOWN  Counter B  5  H1-L5  TOP5N
# 71739  6/22/2019  19:09:35  1  0  DOWN  Counter B  5  H1-L5  TOP5N
#
# [71740 rows x 9 columns]

# %%
X = df.to_numpy()
X = X[:20000,[2, 6]]

# %%
db = DBSCAN(eps=3, min_samples=2).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

# %%
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 2
# Estimated number of noise points: 1

# %%
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
